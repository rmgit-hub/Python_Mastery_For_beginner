# %% [markdown]
# **Variables are like little boxes where you store data.
# Each variable can hold a specific type of data.Depending on the type, you can do different things with them, like doing math with numbers or combining pieces of text.**

# %% [markdown]
# **To create a variable, you just pick a name for it, put an equals sign =, and then assign it a value. For example:**

# %%
First_name = "Alice"
age = 12
print(f"Hello {First_name}, congratulations on your {age}th birthday!")

# %% [markdown]
# **When you write something like First_name = "Alice", what’s actually happening? Where is "Alice" stored?**

# %% [markdown]
# When you create a variable like First_name = "Alice", Python saves the string "Alice" in memory
# and connects the variable First_name to that spot in memory, like a label.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now, if you do something like this:

# %%
# Define new variable
Nickname = "Alice"

# Print values
print("nickname =", Nickname)
print("first_name =", First_name)

# %% [markdown]
# ![variable_assign2.png](data:image/png;base64,...)

# %% [markdown]
# Data types are super important in programming because they help us handle different kinds of data in the best and most accurate way. By choosing the right data type, we make sure our code processes information correctly, reducing errors and making our programs easier to understand and maintain. Each data type is designed for a specific purpose and helps us manage our code better.

# %% [markdown]
# Python offers several data types: Integers (`int`) for whole numbers, Floats (`float`) for decimals, Strings (`str`) for text, Booleans (`bool`) for `True`/`False` values, and Binary Data (`bytes`) for low-level data like files. Using these types correctly helps create efficient and maintainable programs.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Data type conversion in python**
#
#
# Data type conversion in Python is just about changing one type of data to another, like turning a string `"123"` into an integer `123` so you can do math with it, using simple functions like `int()` or `str()`.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Implicit and Explicit Conversion:**
#
# There are two ways to perform data type conversion in Python.
#
# **Implicit Data Type Conversion:**
#
# This happens when Python automatically changes one data type to another behind the scenes, such as in the first code example where Python converts the integer `a` to a float during the operation. This automatic change is known as implicit conversion.
#
# **Explicit Data Type Conversion:**
# [link text](https://)
# On the other hand, explicit conversion is when the programmer manually changes a data type using specific functions like `int()`, `float()`, or `str()`. For instance, in the second example where you convert `3.5` to `3`, you would use `int()` to explicitly convert the float to an integer. This approach gives you more control over how the data is processed in your code.

# %% [markdown]
# **Simple Example Of Implicit  Data Type Conversion**
#
# Behind the scenes, the Python interpreter will implicitly convert the type of a to a float, so the result will be 7.5, not 7.

# %%
a = 4
b = 3.5
c = a + b
print(c)

# %% [markdown]
# **Simple Example Of Explicit  Data Type Conversion**
#
# In this simple number guessing game, the computer picks a random number between 1 and 10, and the player tries to guess it. The player enters a guess, and the game tells them if their guess is correct, too low, or too high. The program uses basic operations like comparing numbers and converting the player’s input from text to a number to make the game work.
#
# Notice how we used the `int()` function to convert the `guess` variable from a string to an integer.

# %%
import random

# Generate a random number between 1 and 10
secret_number = random.randint(1, 10)

# Ask the player to guess the number
guess = input("Guess a number between 1 and 10: ")

# Convert the player's guess from string to integer
guess = int(guess)

# Check if the guess is correct using comparison operators
if guess == secret_number:
    print("Congratulations! You guessed the correct number.")
elif guess < secret_number:
    print("Too low! The correct number was:", secret_number)
else:
    print("Too high! The correct number was:", secret_number)
